# %% [markdown]
# https://www.nvidia.com/en-sg/ai-data-science/foundation-models/
#
# https://build.nvidia.com/microsoft/microsoft-kosmos-2?snippet_tab=Python

# %% [markdown]
# # Foundation model

# %% [markdown]
# A foundation model is a large pre-trained AI model like GPT or CLIP that serves as a general-purpose base for many tasks but faces limitations such as static knowledge, limited domain expertise, weak reasoning over long contexts, lack of real-time access, and potential bias or inaccuracies. Agent tools overcome these limits by connecting the model to external data sources, APIs, specialized models, and memory systems, enabling real-time information retrieval, multi-step reasoning, domain adaptation, and safer, more accurate outputs. This turns a static model into a dynamic, task-oriented AI system capable of handling complex workflows.

# %% [markdown]
# Let see a example of a foundation model. What is it's limitation.
#
# How can we overcome the limitation?
#
# https://build.nvidia.com/moonshotai/kimi-k2-instruct

# %% [markdown]
# Let ask foundation model of the history of Singapore. Check the response is correctly described.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let check current Singapore Weather. Does it give the current answer?
# If not, why can't it provide you the current answer?
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# How can we overcome the limitation of the foundation model?
#
# We use external Tool.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # microsoft kosmos-2 PREVIEW
# Groundbreaking multimodal model designed to understand and reason about visual elements in images.

# %% [markdown]
# Goto this weblink https://build.nvidia.com/microsoft/microsoft-kosmos-2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Get a API Key to run the program
#
# ![image.png](data:image/png;base64,...)

# %%
import requests, base64

invoke_url = "https://ai.api.nvidia.com/v1/vlm/microsoft/kosmos-2"

with open("sample.png", "rb") as f:
    image_b64 = base64.b64encode(f.read()).decode()

assert len(image_b64) < 180_000, \
  "To upload larger images, use the assets API (see docs)"

APIkey =""

headers = {
  "Authorization": "Bearer "+ APIkey,
  "Accept": "application/json"
}

payload = {
  "messages": [
    {
      "role": "user",
      "content": f'Who is in this photo? <img src="data:image/png;base64,{image_b64}" />'
    }
  ],
  "max_tokens": 1024,
  "temperature": 0.20,
  "top_p": 0.20
}

response = requests.post(invoke_url, headers=headers, json=payload)

print(response.json())
# Out:
# {'id': '01887019-e274-429c-ad65-0733b6afd51e', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'A red cube. The image is a close-up of a red cube on a green cube.', 'entities': [{'phrase': 'The image', 'substring': [12, 20], 'bboxes': [[0.015625, 0.015625, 0.984375, 0.984375]]}]}, 'finish_reason': 'stop'}], 'usage': {'completion_tokens': 106, 'prompt_tokens': 80, 'total_tokens': 186}}

# %%
import requests, base64

invoke_url = "https://ai.api.nvidia.com/v1/vlm/microsoft/kosmos-2"

with open("workersafty_small.png", "rb") as f:
    image_b64 = base64.b64encode(f.read()).decode()

assert len(image_b64) < 180_000, \
  "To upload larger images, use the assets API (see docs)"

headers = {
  "Authorization": "Bearer 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",
  "Accept": "application/json"
}

payload = {
  "messages": [
    {
      "role": "user",
      "content": f'Identify the potential safty hazards in the work environment. Provide detail explanation. <img src="data:image/png;base64,{image_b64}" />'
    }
  ],
  "max_tokens": 1024,
  "temperature": 0.20,
  "top_p": 0.20
}

response = requests.post(invoke_url, headers=headers, json=payload)

print(response.json())
# Out:
# {'id': 'd85da533-34c6-4b44-bcac-1bf32d39b5e5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "A man is working on a wooden structure, using a saw to cut through a beam. The potential hazards in this work environment include falls, injuries, and the risk of accidents. Falling from heights, such as from scaffolding, can lead to injuries ranging from minor cuts and bruises to more severe fractures and even head trauma. Additionally, the man's use of a saw can cause sparks or dust to fly, which can be harmful to his eyes and respiratory system. To minimize these risks, it is essential for the man to wear appropriate safety gear, such as a hard hat, safety glasses, and hearing protection, while working on the structure.", 'entities': [{'phrase': 'A man', 'substring': [0, 4], 'bboxes': [[0.390625, 0.328125, 0.578125, 0.734375]]}, {'phrase': 'a wooden structure', 'substring': [20, 37], 'bboxes': [[0.015625, 0.671875, 0.984375, 0.984375]]}, {'phrase': 'a saw', 'substri
# ...

# %% [markdown]
# # Text To Speech (TTS)

# %% [markdown]
# Understanding Text-to-Speech (TTS)
# Text-to-Speech is an AI-driven technology that converts written text into natural-sounding spoken words. Unlike Automatic Speech Recognition (ASR), which translates spoken language into text, TTS works in the opposite direction by transforming text into speech. Modern TTS systems typically follow a two-stage architecture: first, a text analysis frontend that converts text into linguistic and prosodic features, and second, a speech synthesis backend that generates the actual audio.
#
# First Stage: Frontend
#
# Text Processing: The first step involves preparing the text for synthesis. This includes techniques like expanding abbreviations, handling special characters or converting numbers into their spoken form. These steps ensure that the text is clean and ready for the next stages.
# Phonetic Transcription: Once the text is processed, the system converts it into phonemes, the distinct sounds that make up words. This step is essential for accurately capturing how the text should sound when spoken.
# Prosody Modeling: To make the speech sound more natural, prosody modeling is introduced. This step adds rhythm, stress, and intonation to the speech, mimicking the flow of human speech. Without prosody, the speech would sound monotonous and robotic.
# Second Stage: Backend
#
# Speech Synthesis: Finally, the system generates the audio waveforms from the processed text, creating the spoken voice that users hear. This is the culmination of all the previous steps and results in a seamless audio output.
# Press enter or click to view image in full size

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# image source: https://medium.com/@zilliz_learn/from-text-to-speech-a-deep-dive-into-tts-technologies-18ea409f20e8

# %% [markdown]
# https://build.nvidia.com/nvidia/magpie-tts-flow

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Resoureces:
#
# https://medium.com/neuralspace/text-to-speech-101-the-ultimate-guide-9a4b10e20fef
#
#
# https://medium.com/@zilliz_learn/from-text-to-speech-a-deep-dive-into-tts-technologies-18ea409f20e8
